# %%
import nibabel as nib
from nibabel.viewers import OrthoSlicer3D
import skimage.io as io
import numpy as np
# read the nifti file
img=nib.load(r'E:\data\pMCI\ADNI\018_S_0406\MPR____N3\2008-01-25_16_28_25.0\S44966\ADNI_018_S_0406_MR_MPR____N3_Br_20080221170247791_S44966_I91477.nii')
# convert to array
img_arr=img.get_fdata()
# show the shape of the array
print(img_arr.shape)
# Out:
# (256, 256, 170)

# %%
import matplotlib.pyplot as plt
plt.imshow(img_arr[100,:,:])
